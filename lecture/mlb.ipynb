# %%
# Read in the data
import pandas as pd
portfolio_df = pd.read_csv("MLB_distance_matrix.csv", index_col=0)
AmericanLeague = list(portfolio_df.index)    # Row labels from the original DataFrame
NationalLeague = list(portfolio_df.columns)  # Column labels from the original DataFrame
Distance_df = portfolio_df.loc[AmericanLeague, NationalLeague]
